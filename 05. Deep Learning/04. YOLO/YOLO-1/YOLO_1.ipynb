# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 28.4 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
model = YOLO('yolo11n.pt')

# %%
res = model(['/content/Kitchen P_004_View_01-20210228091249457.jpg'])
res[0].save('result.png')
# Out:
# 0: 480x640 1 bowl, 1 microwave, 1 oven, 57.2ms
# Speed: 13.4ms preprocess, 57.2ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
# 'result.png'

# %%
res = model(['/content/Kitchen P_004_View_01-20210228091249457.jpg', '/content/eleph.jpeg' ])
# Out:
# 0: 640x640 1 bowl, 1 microwave, 2 ovens, 35.2ms
# 1: 640x640 1 elephant, 35.2ms
# Speed: 3.8ms preprocess, 35.2ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)

# %%
a = 0
for i in res:
  i.save(f'image{a}.png')
  a += 1

# %%
# !mkdir -p ~/.kaggle
# !cp /content/kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d "abuzarkhaaan/helmetbehncode"
# Out:
# Dataset URL: https://www.kaggle.com/datasets/abuzarkhaaan/helmetbehncode
# License(s): Community Data License Agreement - Permissive - Version 1.0
# ...
#  76% 97.0M/128M [00:00<00:00, 1.02GB/s]
# 100% 128M/128M [00:00<00:00, 969MB/s]

# %%
# !unzip /content/helmetbehncode.zip
# Out:
# Archive:  /content/helmetbehncode.zip
#   inflating: README.dataset.txt
#   inflating: README.roboflow.txt
#   inflating: data.yaml
#   inflating: test/images/IMG_20231211_160448_469_jpg.rf.e9effbbdf65c4e584c8b886f3349c1ff.jpg
#   inflating: test/images/IMG_20231211_160457_277_jpg.rf.46e821190546b198e75e4325a7ba7cbf.jpg
#   inflating: test/images/IMG_20231211_160707_195_jpg.rf.e7421ae41af35ef53af0528343dcf1f7.jpg
#   inflating: test/images/IMG_20231211_160711_086_jpg.rf.2da33e803c2ee5b8bed08fa0de11572c.jpg
#   inflating: test/images/IMG_20231211_160719_285_jpg.rf.8c2a42b2d96877c9bbc73c1539cf466c.jpg
#   inflating: test/images/IMG_20231211_160720_741_jpg.rf.19e1c481dc3c665e91609824f4be2285.jpg
#   inflating: test/images/IMG_20231211_160721_157_jpg.rf.ac4ed2aca8a0fe86f5a50f0055fc40bc.jpg
#   inflating: test/images/IMG_20231211_160721_526_jpg.rf.f0f5b2acd7a3558dd95c9871552dded4.jpg
#   inflating: test/images/IMG_20231211_160724_037_jpg.rf.1e2d8a85faf4a948c9ebea87dc37b6c4.jpg
# ...

# %%
# !yolo mode=train task=detect model=yolov8m.pt data=/content/data.yaml epochs=12 project=/content/output_result
# Out:
# ...
# Ultralytics 8.3.191 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...
