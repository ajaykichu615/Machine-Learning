# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('popular_anime.csv')

# %%
df.head()
# Out:
#       id                              name                             genres  \
# 0  52991     Frieren: Beyond Journey's End          Adventure, Drama, Fantasy
# 1   5114  Fullmetal Alchemist: Brotherhood  Action, Adventure, Drama, Fantasy
# 2   9253                       Steins;Gate            Drama, Sci-Fi, Suspense
# 3  38524   Attack on Titan Season 3 Part 2            Action, Drama, Suspense
# 4  28977                  Gintama Season 4             Action, Comedy, Sci-Fi
#
#   type  episodes           status                 aired_from  \
# 0   TV      28.0  Finished Airing  2023-09-29T00:00:00+00:00
# 1   TV      64.0  Finished Airing  2009-04-05T00:00:00+00:00
# 2   TV      24.0  Finished Airing  2011-04-06T00:00:00+00:00
# 3   TV      10.0  Finished Airing  2019-04-29T00:00:00+00:00
# 4   TV      51.0  Finished Airing  2015-04-08T00:00:00+00:00
#
#                     aired_to duration_per_ep  score  scored_by  rank  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28825 entries, 0 to 28824
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               28825 non-null  int64
#  1   name             28825 non-null  object
#  2   genres           22756 non-null  object
#  3   type             28738 non-null  object
#  4   episodes         28046 non-null  float64
#  5   status           28825 non-null  object
#  6   aired_from       27870 non-null  object
#  7   aired_to         10930 non-null  object
#  8   duration_per_ep  28825 non-null  object
#  9   score            18599 non-null  float64
#  10  scored_by        18599 non-null  float64
#  11  rank             21962 non-null  float64
#  12  rating           28101 non-null  object
#  13  studios          16936 non-null  object
#  14  producers        13452 non-null  object
#  15  image            28825 non-null  object
# ...

# %%
df.isna().sum()
# Out:
# id                     0
# name                   0
# genres              6069
# type                  87
# episodes             779
# status                 0
# aired_from           955
# aired_to           17895
# duration_per_ep        0
# score              10226
# scored_by          10226
# rank                6863
# rating               724
# studios            11889
# producers          15373
# image                  0
# trailer            23351
# synopsis            5368
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isna().sum()
# Out:
# id                 0
# name               0
# genres             0
# type               0
# episodes           0
# status             0
# aired_from         0
# aired_to           0
# duration_per_ep    0
# score              0
# scored_by          0
# rank               0
# rating             0
# studios            0
# producers          0
# image              0
# trailer            0
# synopsis           0
# dtype: int64

# %%
df.shape
# Out:
# (2831, 18)

# %%
df.reset_index(drop=True, inplace=True)

# %%
df.head()
# Out:
#       id                              name                             genres  \
# 0  52991     Frieren: Beyond Journey's End          Adventure, Drama, Fantasy
# 1   5114  Fullmetal Alchemist: Brotherhood  Action, Adventure, Drama, Fantasy
# 2   9253                       Steins;Gate            Drama, Sci-Fi, Suspense
# 3  38524   Attack on Titan Season 3 Part 2            Action, Drama, Suspense
# 4  11061                   Hunter x Hunter         Action, Adventure, Fantasy
#
#   type  episodes           status                 aired_from  \
# 0   TV      28.0  Finished Airing  2023-09-29T00:00:00+00:00
# 1   TV      64.0  Finished Airing  2009-04-05T00:00:00+00:00
# 2   TV      24.0  Finished Airing  2011-04-06T00:00:00+00:00
# 3   TV      10.0  Finished Airing  2019-04-29T00:00:00+00:00
# 4   TV     148.0  Finished Airing  2011-10-02T00:00:00+00:00
#
#                     aired_to duration_per_ep  score  scored_by  rank  \
# ...

# %%
df.drop(columns=['image','trailer','synopsis'], inplace=True)

# %%
df.drop(columns=['id'], inplace=True)

# %%
df.head()
# Out:
#                                name                             genres type  \
# 0     Frieren: Beyond Journey's End          Adventure, Drama, Fantasy   TV
# 1  Fullmetal Alchemist: Brotherhood  Action, Adventure, Drama, Fantasy   TV
# 2                       Steins;Gate            Drama, Sci-Fi, Suspense   TV
# 3   Attack on Titan Season 3 Part 2            Action, Drama, Suspense   TV
# 4                   Hunter x Hunter         Action, Adventure, Fantasy   TV
#
#    episodes           status                          aired_from  \
# 0        28  Finished Airing 1970-01-01 00:00:00.000000028+00:00
# 1        64  Finished Airing 1970-01-01 00:00:00.000000064+00:00
# 2        24  Finished Airing 1970-01-01 00:00:00.000000024+00:00
# 3        10  Finished Airing 1970-01-01 00:00:00.000000010+00:00
# 4       148  Finished Airing 1970-01-01 00:00:00.000000148+00:00
#
#                    aired_to duration_per_ep  score  scored_by  rank  \
# ...

# %%
df.dtypes
# Out:
# name                            object
# genres                          object
# type                            object
# episodes                         int64
# status                          object
# aired_from         datetime64[ns, UTC]
# aired_to           datetime64[ns, UTC]
# duration_per_ep                 object
# score                          float64
# scored_by                      float64
# rank                           float64
# rating                          object
# studios                         object
# producers                       object
# dtype: object

# %%
df['episodes']=df['episodes'].astype('int')

# %%
df['aired_from']=pd.to_datetime(df['aired_from'].dt.tz_localize('UTC')
)

# %%
df['aired_to']=pd.to_datetime(df['aired_to'])

# %%
df_movies=df[df['type']=='Movie']
df_movies.reset_index(drop=True,inplace=True)
df_movies
# Out:
#                                                 name  \
# 0  Legend of the Galactic Heroes: Die Neue These ...
# 1                             Bocchi the Rock! Movie
# 2  Legend of the Galactic Heroes: Die Neue These ...
# 3              Dead Dead Demons Dededede Destruction
# 4                        Re:cycle of the Penguindrum
# 5                                 Koi Suru Shirokuma
# 6                             Wave!! Surfing Yappe!!
# 7                                     Yuuyake Dandan
# 8                  Collar x Malice Movie: Deep Cover
#
#                                               genres   type  episodes  \
# 0                                      Drama, Sci-Fi  Movie        12
# 1                                             Comedy  Movie         2
# 2                                      Drama, Sci-Fi  Movie        12
# 3                                      Drama, Sci-Fi  Movie         2
# 4  Avant Garde, Comedy, Drama, Mystery, Supernatural  Movie         2
# ...

# %%
df_movies.shape
# Out:
# (9, 14)

# %%
df_tv=df[df['type']=='TV']
df_tv.reset_index(drop=True, inplace=True)
df_tv
# Out:
#                                   name                             genres  \
# 0        Frieren: Beyond Journey's End          Adventure, Drama, Fantasy
# 1     Fullmetal Alchemist: Brotherhood  Action, Adventure, Drama, Fantasy
# 2                          Steins;Gate            Drama, Sci-Fi, Suspense
# 3      Attack on Titan Season 3 Part 2            Action, Drama, Suspense
# 4                      Hunter x Hunter         Action, Adventure, Fantasy
# ...                                ...                                ...
# 2527                        Conception   Action, Comedy, Fantasy, Romance
# 2528                           Gibiate    Action, Fantasy, Horror, Sci-Fi
# 2529                     Rusted Armors                             Action
# 2530                              Pupa                   Horror, Suspense
# 2531                            Ex-Arm                     Action, Sci-Fi
#
#      type  episodes           status                          aired_from  \
# ...

# %%
df['type'].unique()
# Out:
# array(['TV', 'OVA', 'TV Special', 'ONA', 'Special', 'Movie'], dtype=object)
